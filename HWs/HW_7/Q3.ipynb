# %% [markdown]
# # Install mtm

# %%
! pip install mtm

# %% [markdown]
# # Import Libraries

# %%
import mtm
from mtm import matchTemplates
from mtm.detection import plotDetections
import matplotlib.pyplot as plt

# %% [markdown]
# # Read And Display Image

# %%
# Read the image file using plt.imread
image_path = '/content/coins.png'
coins_image = plt.imread(image_path)

# Display the full image using plt.imshow
plt.imshow(coins_image, cmap='gray')
plt.axis('off')
plt.title('Full Image of Coins')
plt.show()

# %% [markdown]
# # Extract a sub-region (small coin)

# %%
small_coin_region = coins_image[102:148, 22:68]  # Extract the region of the small coin

# Display the sub-region (small coin) using plt.imshow
plt.imshow(small_coin_region, cmap='gray')
plt.axis('off')
plt.title('Extracted Small Coin Region')
plt.show()

# %% [markdown]
# # Extraction and Visualization of Large Coin Region

# %%
largeCoin = image[14:14+61,302:302+67]
plt.figure(0)
plt.imshow(largeCoin, cmap="gray")

# %% [markdown]
# # Template Matching using Multiple Templates

# %%
# Create a list holding the small and large coin templates
coin_templates = [smallCoin, largeCoin]

# Match templates to the image using the matchTemplates function
# This function searches for the templates in the image and returns a list of detections
detections_list = matchTemplates(image, listTemplates, scoreThreshold=0.4, maxOverlap=0)
plotDetections(image, listDetections)
